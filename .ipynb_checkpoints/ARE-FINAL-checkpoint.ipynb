# %%
from random import randint
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Dynamique de déplacement de voitures dans un système autoroutier

# %% [markdown]
# [FR]
#
# Nous avons choisi d’étudier les dynamiques de déplacement des voitures sur différents types de routes afin de pouvoir comprendre quelle type de route est le plus efficace et comment pourrait-on faire pour fluidifier les trafics routiers.
#
# Nous avons donc créer plusieurs types de routes sur lesquelles nous avons simuler différents groupes de voitures qui agissent entres elles et qui ont une certaine probabilité d’avoir un accident.
#
# On s’attendait au debut à constater que si une route allant d’un point A à un point B etait large et utilisé et plus il etait nécessaire de la prendre pour arriver le plus rapidement à déstination.
#
# Or nous avons pu observé qu'en rentrant des probabilités accidentelles propre aux différents types de routes, il était au final largement plus intéressant de prendre une route à une voie plus longue qu'une route à 2 voie plus courte.
#
# Notre conclusion est assimilable à l'exemple de Pigou (1920)
#
# [EN]
#
# We chose to study the dynamics of moving cars on different types of roads in order to understand which type of road is the most efficient and how could we make traffic flows smoother.
#
# So we created several types of roads on which we simulate different groups of cars that act between them and have a certain probability of having an accident.
#
# It was initially expected that if a route from point A to point B was wide and used, it was necessary to take it to reach the destination as quickly as possible.
#
# However, we observed that, in entering accidental probabilities specific to the different types of roads, it was in fact much more interesting to take a longer one-lane road than a shorter two-lane road.
#
# Our conclusion is comparable to the example of Pigou (1920)

# %% [markdown]
# # 1. Modèle de route à une voie

# %% [markdown]
# ### Comment modéliser un tel phénomène ?
#
# Considérons un ensemble de **voitures**. Par soucis de simplicité nous faisons abstraction des variations de vitesses et considérons que toutes les voitures se déplacent soit à une vitesse constante, soit à une vitesse nulle si elles sont à l'arrêt. Une voiture à une probabilité $p$ de tomber en panne pendant un temps $t$. Afin de pouvoir obtenir une simulation visualisable, nous choisirons une probabilité assez élevée (0.5% pour chaque tour pour chaque voiture).
# Chaque individu du groupe de voiture est modélisé par un son numero d'arrivé sur la route ce qui nous permet de "tracer" cette dernière sur la route.

# %% [markdown]
# Commençons par créer notre classe voiture.
# On définit sa position sur la route et sur la voie, le temps qu'elle reste sur cette route, sa probabilité d'avoir un accident, son etat (si accidenté ou non) ainsi que son numero d'arrivé sur la route.
# On définit ensuite une fonction qui va permettre aux voitures de rouler.
# Si elles sont dans un etat non accidenté, elles peuvent avancer et ont une probabilité $p$ de tomber en panne, tandis que si une voiture est accidentée, elle ne peut pas re-tomber en passe et ne peut pas avancer.

# %%
class voiture:
    
    def __init__(self, proba,name):
        self.x = 0
        self.y = 1
        self.temps = 0
        self.proba = proba
        self.etat = 0 #si different de 0 alors accident et stop traffic
        self.j = name

    def roule(self):
        self.temps += 1
        if self.etat == 0:
            self.x += 1
            if self.proba == 0 :
                self.accident = 0
            else :
                self.accident = randint(1, self.proba)
                #Il y a une autre façon de génerer une probabilité que l'on
                #dans les simulation qui suivront.
            if self.accident == 1 and self.x>0:
                self.etat = 5
        else :
            self.etat += -1

# %% [markdown]
# Créons maintenant notre classe voiture.
# On définit la liste de voitures qui va la traverser, le débit de voiture sur la route, la grille matricielle sur laquelle on representa les voitures avec différentes températures afin de pouvoir obtenir une visulation graphique de l'avancé à l'aide de np.zeros, la distance de la route, la probabilité qu'ont les voitures de tomber en panne ainsi que le nombre des voitures qui ont finit de traverser.

# %%
class route:
    
    def __init__(self, debit, distance, proba):
        self.voitures = [voiture(proba,0)]
        self.debit = debit
        #fin de l'ajout
        
        self.grid = np.zeros(shape=(distance,3))
        self.distance = distance
        self.state_route = self.grid
        self.proba = proba
        
        #truc pour le temps
        self.inc = 0
        self.voitures_passe = 0

    def update_route(self):
        
        ancienne_route = self.state_route.copy()
        
        self.state_route = np.zeros((self.distance, 3))
        
        for item in self.voitures:
            if item.x>=0 and item.x<(self.distance-1) and ancienne_route[item.x+1][item.y] != 0:
                self.etat = 3
                item.temps += 1
                self.state_route[item.x][item.y] = 6
            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                    self.state_route[item.x][item.y] = 10
                    if item.etat != 0 :
                        self.state_route[item.x][item.y] = 6
        print([item.x for item in self.voitures])
        
        #generation de nouvelles voitures
        self.inc += 1
        if self.inc%self.debit == 0 and self.state_route[1][0] == 0 and self.state_route[1][1] == 0 and self.state_route[1][2] == 0:
            self.voitures.append(voiture(self.proba,self.inc))
            print("plop ! une voiture est entrée dans le lobby- autoroute !!")
            
        #compteur de voitures passées
        for i in self.voitures:
            if i.x == self.distance :
                print( "ping ! la voiture ",i.j," a traversee l'autoroute ! elle a mis",i.temps)
                del i

# %% [markdown]
# La fonction résolution permet d'augmenter la taille de l'image qu'on obtient, nous permettant de faire une video de meilleure qualitée.

# %%
def resolution(data) :
    new_data = np.zeros(np.array(data.shape) * 10)

    for j in range(data.shape[0]):
        for k in range(data.shape[1]):
            new_data[j * 10: (j+1) * 10, k * 10: (k+1) * 10] = data[j, k]

    return new_data

# %% [markdown]
# On test notre route en lui atribuant une distance de 2, une route de longueur 15 et une probabilité de tomber en panne de 1%.

# %%
road = route(2,15,100)

for j in range(100):
    
    road.update_route()
    road.state_route
    plt.imshow(road.state_route, vmin=0, vmax=13, cmap="hot")
    plt.imsave("resultat_{}.png".format(j),resolution(road.state_route))
    plt.colorbar()
    plt.show()
    plt.pause(0.1)
    plt.cla()
# Out:
# [1]
# [2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [3, 1]
# [4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [5, 3, 1]
# [6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [7, 5, 3, 1]
# [8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [9, 7, 5, 3, 1]
# [10, 7, 6, 3, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [11, 7, 6, 3, 2, 1]
# [12, 7, 6, 3, 2, 1]
# [13, 7, 6, 3, 2, 1]
# [14, 7, 6, 3, 2, 1]
# [15, 8, 6, 4, 2, 1]
# ('ping ! la voiture ', 0, " a traversee l'autoroute ! elle a mis", 15)
# [16, 9, 7, 5, 3, 1]
# [17, 10, 8, 6, 4, 2]
# [18, 11, 9, 7, 5, 3]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [19, 12, 10, 8, 6, 4, 1]
# [20, 13, 11, 9, 7, 5, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [21, 14, 12, 10, 8, 6, 3, 1]
# [22, 15, 13, 11, 9, 7, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 20)
# [23, 16, 14, 12, 10, 8, 5, 3, 1]
# [24, 17, 15, 12, 11, 9, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 4, " a traversee l'autoroute ! elle a mis", 20)
# [25, 18, 16, 12, 11, 10, 7, 5, 3, 1]
# [26, 19, 17, 12, 11, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [27, 20, 18, 12, 11, 10, 9, 7, 5, 3, 1]
# [28, 21, 19, 12, 11, 10, 9, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [29, 22, 20, 13, 11, 10, 9, 8, 7, 5, 3, 1]
# [30, 23, 21, 14, 12, 10, 9, 8, 7, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [31, 24, 22, 15, 13, 11, 9, 8, 7, 6, 5, 3, 1]
# ('ping ! la voiture ', 6, " a traversee l'autoroute ! elle a mis", 25)
# [32, 25, 23, 16, 14, 12, 10, 8, 7, 6, 5, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [33, 26, 24, 17, 15, 13, 11, 9, 7, 6, 5, 4, 3, 1]
# ('ping ! la voiture ', 8, " a traversee l'autoroute ! elle a mis", 25)
# [34, 27, 25, 18, 16, 14, 12, 10, 8, 6, 5, 4, 3, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [35, 28, 26, 19, 17, 15, 13, 11, 9, 7, 5, 4, 3, 2, 1]
# ('ping ! la voiture ', 10, " a traversee l'autoroute ! elle a mis", 25)
# [36, 29, 27, 20, 18, 16, 14, 12, 10, 8, 6, 4, 3, 2, 1]
# [37, 30, 28, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 2, 1]
# ('ping ! la voiture ', 18, " a traversee l'autoroute ! elle a mis", 19)
# [38, 31, 29, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 1]
# [39, 32, 30, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 20, " a traversee l'autoroute ! elle a mis", 19)
# [40, 33, 31, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [41, 34, 32, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 22, " a traversee l'autoroute ! elle a mis", 19)
# [42, 35, 33, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [43, 36, 34, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 24, " a traversee l'autoroute ! elle a mis", 19)
# [44, 37, 35, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [45, 38, 36, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 26, " a traversee l'autoroute ! elle a mis", 19)
# [46, 39, 37, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [47, 40, 38, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 28, " a traversee l'autoroute ! elle a mis", 19)
# [48, 41, 38, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [49, 42, 38, 33, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 30, " a traversee l'autoroute ! elle a mis", 19)
# [50, 43, 38, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [51, 44, 38, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 32, " a traversee l'autoroute ! elle a mis", 19)
# [52, 45, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [53, 46, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 34, " a traversee l'autoroute ! elle a mis", 19)
# [54, 47, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [55, 48, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 40, " a traversee l'autoroute ! elle a mis", 15)
# [56, 49, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [57, 50, 43, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 17, 14, 13, 11, 9, 7, 5, 3, 1]
# [58, 50, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 14, 13, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [59, 50, 45, 43, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 19, 14, 13, 12, 11, 9, 7, 5, 3, 1]
# [60, 50, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 14, 13, 12, 11, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [61, 50, 47, 45, 43, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 21, 14, 13, 12, 11, 10, 9, 7, 5, 3, 1]
# [62, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 15, 13, 12, 11, 10, 9, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 42, " a traversee l'autoroute ! elle a mis", 20)
# [63, 51, 49, 47, 45, 43, 41, 39, 37, 35, 33, 31, 29, 27, 25, 23, 16, 14, 12, 11, 10, 9, 8, 7, 5, 3, 1]
# [64, 52, 50, 48, 46, 44, 42, 39, 38, 36, 34, 32, 30, 28, 26, 24, 17, 15, 13, 11, 10, 9, 8, 7, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 44, " a traversee l'autoroute ! elle a mis", 20)
# [65, 53, 51, 49, 47, 45, 43, 39, 39, 37, 35, 33, 31, 29, 27, 25, 18, 16, 14, 12, 10, 9, 8, 7, 6, 5, 3, 1]
# [66, 54, 52, 50, 48, 46, 44, 39, 40, 38, 36, 34, 32, 30, 28, 26, 19, 17, 15, 13, 11, 9, 8, 7, 6, 5, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 46, " a traversee l'autoroute ! elle a mis", 20)
# [67, 55, 53, 51, 49, 47, 45, 39, 41, 39, 37, 35, 33, 31, 29, 27, 20, 18, 16, 14, 12, 10, 8, 7, 6, 5, 4, 3, 1]
# [68, 56, 54, 52, 50, 48, 46, 39, 42, 40, 38, 36, 34, 32, 30, 28, 21, 19, 17, 15, 13, 11, 9, 7, 6, 5, 4, 3, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ',
 3]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 82, " a traversee l'autoroute ! elle a mis", 16)
# [99, 87, 85, 78, 78, 79, 72, 70, 73, 71, 69, 62, 60, 60, 61, 59, 52, 48, 48, 46, 44, 42, 40, 33, 31, 34, 32, 30, 28, 26, 23, 21, 19, 15, 15, 13, 11, 4, 1]
# ('ping ! la voiture ', 82, " a traversee l'autoroute ! elle a mis", 17)
# ('ping ! la voiture ', 84, " a traversee l'autoroute ! elle a mis", 15)
# [100, 88, 86, 79, 78, 80, 73, 71, 74, 72, 70, 63, 61, 60, 62, 60, 53, 48, 49, 47, 45, 43, 41, 34, 32, 35, 33, 31, 29, 27, 24, 22, 20, 15, 16, 14, 12, 5, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 82, " a traversee l'autoroute ! elle a mis", 18)

# %% [markdown]
# # 2. Modèle de route à une voie avec une sortie

# %% [markdown]
# Dans cette seconde partie nous utiliserons une route simulaire à celle simulée précedemment qui aura en plus une sortie de voie placée sur la route.

# %% [markdown]
# On rajoute à la classe voiture une valeur immun qui fera en sorte que, si la voiture a pris la sortie, cette dernière ne pourra pas avoir d'accident.

# %%
class voiture:
    
    def __init__(self, proba,name):
        self.x = 0
        self.y = 1
        self.temps = 0
        self.proba = proba
        self.etat = 0 #si different de 0 alors accident et stop traffic
        self.j = name
        self.immun = 0 #immunisé d'accidents si sortie de route

    def roule(self):
        self.temps += 1
        if self.etat == 0:
            self.x += 1
            if self.proba == 0 :
                self.accident = 0
            else :
                self.accident = randint(1, self.proba)
                #Il y a une autre façon de génerer une probabilité que l'on
                #dans les simulation qui suivront.
            if self.accident == 1 and self.x>0 and self.immun == 0:
                #si la voiture est acidentée elle ne sera pas accidentée.
                self.etat = 5
        else :
            self.etat += -1

# %% [markdown]
# On initialisera maintenant la route en lui atribuant la valeur de la sortie souhatée, ainsi, si la une voiture est embouteillée à cet emplacement, elle aura la possibilité de prendre la sortie.

# %%
class route:
    
    def __init__(self, debit, distance, proba, sortie):
        self.voitures = [voiture(proba,0)]
        self.debit = debit
        #fin de l'ajout
        self.sortie = sortie
        self.grid = np.zeros(shape=(distance,5))
        self.distance = distance
        self.state_route = self.grid
        self.proba = proba
        
        #truc pour le temps
        self.inc = 0
        self.voitures_passe = 0

    def update_route(self):
        
        ancienne_route = self.state_route.copy()
        
        self.state_route = np.zeros((self.distance, 5))
        
        for item in self.voitures:
            if item.x>=0 and item.x<(self.distance-1) and ancienne_route[item.x+1][item.y] != 0:
                if item.x == self.sortie :
                    #la voiture peut prendre la sortie, on la rend immunisé pour les accidents en 
                    #affectant une valeur à immun. On change aussi ses coordonnée et on la place sur
                    #la route.
                    item.immun = 1
                    item.y = 3
                    self.state_route[item.x][item.y] = 10
                else : 
                    self.etat = 3
                    item.temps += 1
                    self.state_route[item.x][item.y] = 6
            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                    self.state_route[item.x][item.y] = 10
                    if item.etat != 0 :
                        self.state_route[item.x][item.y] = 6
        print([item.x for item in self.voitures])
        
        #generation de nouvelles voitures
        self.inc += 1
        if self.inc%self.debit == 0 and self.state_route[1][0] == 0 and self.state_route[1][1] == 0 and self.state_route[1][2] == 0:
            self.voitures.append(voiture(self.proba,self.inc))
            print("plop ! une voiture est entrée dans le lobby- autoroute !!")
            
        #compteur de voitures passées
        for i in self.voitures:
            if i.x == self.distance :
                print( "ping ! la voiture ",i.j," a traversee l'autoroute ! elle a mis",i.temps)
                del i

# %%
def resolution(data) :
    new_data = np.zeros(np.array(data.shape) * 10)

    for j in range(data.shape[0]):
        for k in range(data.shape[1]):
            new_data[j * 10: (j+1) * 10, k * 10: (k+1) * 10] = data[j, k]

    return new_data

# %%
road = route(2,15,25,7)

for j in range(100):
    
    road.update_route()
    road.state_route
    plt.imshow(road.state_route, vmin=0, vmax=13, cmap="hot")
    plt.imsave("resultat_{}.png".format(j),resolution(road.state_route))
    plt.colorbar()
    plt.show()
    plt.pause(0.1)
    plt.cla()
# Out:
# [1]
# [2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [3, 1]
# [4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [5, 3, 1]
# [6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [7, 5, 3, 1]
# [8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [9, 7, 5, 3, 1]
# [10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [11, 9, 7, 5, 3, 1]
# [12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [13, 11, 9, 7, 5, 3, 1]
# [14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 0, " a traversee l'autoroute ! elle a mis", 15)
# [16, 14, 12, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [17, 15, 13, 11, 9, 7, 5, 3, 1]
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 15)
# [18, 15, 14, 12, 10, 7, 6, 3, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 16)
# [19, 15, 15, 13, 11, 7, 6, 3, 2, 1]
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 17)
# ('ping ! la voiture ', 4, " a traversee l'autoroute ! elle a mis", 15)
# [20, 15, 16, 14, 12, 7, 6, 3, 2, 1]
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 18)
# [21, 15, 17, 15, 13, 7, 6, 3, 2, 1]
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 19)
# ('ping ! la voiture ', 6, " a traversee l'autoroute ! elle a mis", 15)
# [21, 15, 18, 16, 14, 7, 6, 3, 2, 1]
# ('ping ! la voiture ', 2, " a traversee l'autoroute ! elle a mis", 20)
# [21, 16, 19, 17, 15, 8, 6, 4, 2, 1]
# ('ping ! la voiture ', 8, " a traversee l'autoroute ! elle a mis", 15)
# [21, 17, 20, 17, 16, 9, 7, 5, 3, 1]
# [21, 18, 21, 17, 17, 10, 8, 6, 4, 2]
# [21, 19, 22, 17, 18, 11, 9, 7, 5, 3]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [22, 20, 23, 17, 19, 12, 10, 8, 6, 4, 1]
# [23, 21, 24, 17, 20, 13, 11, 9, 7, 5, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# [24, 22, 25, 18, 21, 14, 12, 10, 8, 6, 3, 1]
# [25, 23, 26, 19, 22, 15, 13, 11, 9, 7, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 10, " a traversee l'autoroute ! elle a mis", 20)
# [26, 24, 27, 20, 23, 16, 14, 12, 10, 8, 5, 3, 1]
# [27, 25, 28, 21, 24, 17, 15, 13, 11, 9, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 12, " a traversee l'autoroute ! elle a mis", 20)
# [28, 26, 29, 22, 25, 18, 16, 14, 12, 10, 7, 5, 3, 1]
# [29, 27, 30, 23, 25, 19, 17, 15, 13, 10, 8, 6, 4, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 14, " a traversee l'autoroute ! elle a mis", 20)
# [30, 28, 31, 24, 25, 20, 18, 16, 14, 10, 9, 7, 5, 3, 1]
# [31, 29, 32, 25, 25, 21, 19, 17, 15, 10, 9, 8, 6, 4, 1]
# ('ping ! la voiture ', 16, " a traversee l'autoroute ! elle a mis", 20)
# [32, 30, 33, 26, 25, 22, 20, 18, 16, 10, 9, 8, 7, 5, 1]
# [33, 31, 34, 27, 25, 23, 20, 19, 17, 10, 9, 8, 7, 6, 1]
# [34, 32, 35, 28, 26, 24, 20, 20, 18, 11, 9, 8, 8, 7, 1]
# [35, 33, 36, 29, 26, 25, 20, 21, 19, 12, 10, 8, 9, 7, 1]
# [36, 34, 37, 30, 26, 26, 20, 22, 20, 13, 10, 9, 10, 8, 2]
# [37, 35, 38, 31, 26, 27, 20, 23, 21, 14, 10, 9, 11, 9, 3]
# plop ! une voiture est entrée dans le lobby- autoroute !!
#
 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 78, " a traversee l'autoroute ! elle a mis", 20)
# [83, 87, 80, 83, 66, 84, 57, 80, 68, 71, 56, 57, 68, 66, 50, 42, 44, 37, 40, 38, 26, 23, 26, 24, 22, 16, 14, 12, 6, 5, 4, 3, 1]
# [83, 88, 81, 84, 67, 85, 58, 81, 69, 71, 56, 58, 69, 67, 51, 43, 45, 38, 41, 39, 27, 23, 27, 25, 23, 17, 15, 13, 6, 5, 4, 3, 2]
# plop ! une voiture est entrée dans le lobby- autoroute !!
# ('ping ! la voiture ', 80, " a traversee l'autoroute ! elle a mis", 20)

# %% [markdown]
# # 3. Modèle de route à deux voies sans changement de voie.

# %% [markdown]
# Dans cette partie nous simulerons 2 routes simulaires à celles simulées précedemment.
#
# ( possibilitée de passer directement à la partie suivante )

# %% [markdown]
# La classe voiture est identique à celle de base excepté qu'elle prend maintenant un paramètre en plus, la couleur qui la définit, afin de différencier les voitures des deux voies.

# %%
class voiture:
    
    def __init__(self, proba, name, couleur):
        self.x = 0
        self.temps = 0
        self.proba = proba
        self.etat = 0 #si different de 0 alors accident et stop traffic
        self.j = name
        self.couleur = couleur
        self.accident = 0
        self.temp = 0

    #la fonction qui fait rouler les voitures
    def roule(self):
        #sert à connaitre le temps mis par une voiture pour traverser la route
        self.temp += 1
        if self.etat == 0: # si la voiture n'est pas accidentée
            self.x = self.x + 1
            #seconde facon d'utiliser les probabilitées
            if int(np.random.uniform(0,1) < self.proba):
                self.etat = 6
        else :
            self.etat += -1

# %% [markdown]
# Il est donc nécessaire de générer deux listes distinctes pour générer deux groupes de voiture indépendants que l'on fera rouler de la même fçon que précedemment.

# %%
class route:
    
    def __init__(self, debit, distance, proba):
        #1er groupe de voitures :
        self.voitures1 = [voiture(proba=proba, name=0, couleur=9)]
        #2eme groupe de voitures :
        self.voitures2 = [voiture(proba=proba, name=0, couleur=13)]
        self.debit = debit
        
        self.grid = np.zeros(shape=(distance,5))
        self.distance = distance
        self.state_route = np.zeros((self.distance, 5))
        self.proba = proba
    
        self.inc = 0
        self.voitures_passe = 0

    def update_route(self):
        
        ancienne_route = self.state_route.copy()
    
        self.state_route = ancienne_route
        self.state_route[:, 1] = 0

        for item in self.voitures1: #voie gauche
            ### Si il y a blocage devant et que je peux passer sur l'autre voie
            if item.x >= 0 and item.x < (self.distance -1) \
                           and ancienne_route[item.x + 1][1] != 0:
                print("stop")
                item.etat = 2
                self.state_route[item.x][1] = 5 # couleur arret 

            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                        self.state_route[item.x][1] = item.couleur#couleur gauche
                        if item.etat != 0 : # si accident sur le .roule()
                            self.state_route[item.x][1] = 5 #couleur arret
                
            #print(' emplacement1 : {} voit num: '.format(item.x), item.j)
        self.state_route[:, 3] = 0
        
        for item in self.voitures2:
            if item.x>=0 and item.x<(self.distance-1) \
                         and self.state_route[item.x + 1][3] != 0:
                print("stop")
                item.etat = 2
                self.state_route[item.x][3] = 5 # couleur arret 

            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                        self.state_route[item.x][3] = item.couleur
                        if item.etat != 0 :
                            self.state_route[item.x][3] = 5
                 
            #print([item.x for item in self.voitures])
        
        #generation de nouvelles voitures
        self.inc += 1
        #On génere ici la première liste de voitures
        
        if self.inc%self.debit == 0 and self.state_route[0][1] == 0 and self.state_route[1][1] == 0:
            self.voitures1.append(voiture(self.proba,self.inc,9))
            print("plop ! une voiture est entrée dans l'autoroute !!")
            
        #On génere ici la seconde liste de voitures
        
        if self.inc%self.debit == 0 and self.state_route[0][3] == 0 and self.state_route[1][3] == 0:
            self.voitures2.append(voiture(self.proba,self.inc,13))
            print("plop ! une voiture est entrée dans l'autoroute !!")
        
        #compteur de voitures passées
        #for i in self.voitures1:
            #if i.x == self.distance :
                #print( "ping ! la voiture ",i.j," a traversee l'autoroute ! elle a mis",i.temps)
                #del i

# %%
def resolution(data) :
    new_data = np.zeros(np.array(data.shape) * 10)

    for j in range(data.shape[0]):
        for k in range(data.shape[1]):
            new_data[j * 10: (j+1) * 10, k * 10: (k+1) * 10] = data[j, k]

    return new_data

# %%
import matplotlib.image as mpimg

road = route(4,15, 0.01)
for j in range(100):
    road.update_route()
    road.state_route
    
    plt.imshow(road.state_route, vmin=0, vmax=13, cmap="hot")
    #plt.imsave("resultat_{}.png".format(j),resolution(road.state_route))
    plt.colorbar()
    plt.show()
    plt.pause(0.1)
    plt.cla()
# Out:
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# stop
# stop
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# stop
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!

# %% [markdown]
# # 4. Modèle de route à deux voies sans changement de voie.

# %% [markdown]
# Dans cette dernière partie, nous simulerons donc de la même façon que précedemment 2 routes distinctes. Ici en revanche nous ferons intéragir les 2 groupes de voitures entre eux. Nous ferons en sorte que lorsqu'une voiture est bloquée sur la route elle passe sur l'autre route si elle en a la possibilitée.

# %% [markdown]
# On utilise la même classe voiture utilisée précedemment.

# %%
class voiture:
    
    def __init__(self, proba, name, couleur):
        self.x = 0
        self.temps = 0
        self.proba = proba
        self.etat = 0 #si different de 0 alors accident et stop traffic
        self.j = name
        self.couleur = couleur
        self.accident = 0
        self.temp = 0

    #la fonction qui fait rouler les voitures
    def roule(self):
        #sert à connaitre le temps mis par une voiture pour traverser la route
        self.temp += 1
        if self.etat == 0: # si la voiture n'est pas accidentée
            self.x = self.x + 1
            
            if int(np.random.uniform(0,1) < self.proba):
                self.etat = 6
        else :
            self.etat += -1

# %% [markdown]
# Nous allons donc comme précedemment génerer deux listes indépendentes. Afin de faire passer une voiture d'une voie à l'autre il sera necessaire de regarder si la voiture à la place pour se joindre à l'autre liste, de l'ajouter à l'autre liste au bon emplacement ainsi que de la supprimer de la liste initiale.

# %%
class route:
    
    def __init__(self, debit, distance, proba):
        self.voitures1 = [voiture(proba=proba, name=0, couleur=9)]
        self.voitures2 = [voiture(proba=proba, name=0, couleur=13)]
        self.debit = debit
        self.sortie = 8
        
        self.grid = np.zeros(shape=(distance,5))
        self.distance = distance
        self.state_route = np.zeros((self.distance, 5))
        self.proba = proba
    
        self.inc = 0
        self.voitures_passe = 0

    def update_route(self):
        
        ancienne_route = self.state_route.copy()
    
        self.state_route = ancienne_route
        self.state_route[:, 1] = 0

        for idx, item in enumerate(self.voitures1): #voie gauche
            ### Si il y a blocage devant et que je peux passer sur l'autre voie
            if item.x >= 0 and item.x < (self.distance -1) \
                           and ancienne_route[item.x + 1][1] != 0:
                    
                item.temp += 1
                
                if ancienne_route[item.x - 1][3] == 0 \
                   and ancienne_route[item.x][3] == 0 \
                   and ancienne_route[item.x + 1][3] == 0:

                    self.state_route[item.x][3] = item.couleur #couleur gauche
                    item.etat = 0
                    
                    #On ajoute la voiture dans l'autre liste et on la supprime de la liste initiale.
                    for i in range(len(self.voitures2)) :
                    
                        if self.voitures2[i].x < item.x :
                            self.voitures2.insert(i, item)
                            print(len(self.voitures1))
                            self.voitures1 = [x for i, x in enumerate(self.voitures1) if i != idx]
                            print(len(self.voitures1))
                            print("voiture de la voie 1 supprimee a la position: {}".format(item.x))
                            break
                else:
                    print("stop")
                    item.etat = 2
                    self.state_route[item.x][1] = 5 # couleur arret
                    

            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                        self.state_route[item.x][1] = item.couleur#couleur gauche
                        if item.etat != 0 : # si accident sur le .roule()
                            self.state_route[item.x][1] = 5 #couleur arret
                
            #print(' emplacement1 : {} voit num: '.format(item.x), item.j)
        self.state_route[:, 3] = 0
        
        for idx, item in enumerate(self.voitures2):
            if item.x>=0 and item.x<(self.distance-1) \
                         and self.state_route[item.x + 1][3] != 0:
                    
                item.temp += 1
                
                if self.state_route[item.x - 1][1] == 0 and self.state_route[item.x][1] == 0 \
                         and self.state_route[item.x + 1][1] == 0:
                    self.state_route[item.x][1] = item.couleur
                    item.etat = 0

                    for i in range(len(self.voitures1)):
                        if self.voitures1[i].x < item.x :
                            self.voitures1.insert(i, item)
                            print("voiture de la voie 3 supprimee a la position: {}".format(item.x))
                            print(len(self.voitures2))
                            self.voitures2 = [x for i, x in enumerate(self.voitures2) if i != idx]
                            print(len(self.voitures2))
                            break

                else:
                    item.etat = 2
                    self.state_route[item.x][3] = 5 #arret
                

            else :
                item.roule()
                if item.x >= 0 and item.x < self.distance:
                        self.state_route[item.x][3] = item.couleur
                        if item.etat != 0 :
                            self.state_route[item.x][3] = 5
                 
            #print([item.x for item in self.voitures])
        
        #generation de nouvelles voitures
        self.inc += 1
        if self.inc%self.debit == 0 and self.state_route[0][1] == 0 and self.state_route[1][1] == 0:
            self.voitures1.append(voiture(self.proba,self.inc,9))
            print("plop ! une voiture est entrée dans l'autoroute !!")
        if self.inc%self.debit == 0 and self.state_route[0][3] == 0 and self.state_route[1][3] == 0:
            self.voitures2.append(voiture(self.proba,self.inc,13))
            print("plop ! une voiture est entrée dans l'autoroute !!")
        
        #compteur de voitures passées
        #for i in self.voitures1:
            #if i.x == self.distance :
                #print( "ping ! la voiture ",i.j," a traversee l'autoroute ! elle a mis",i.temps)
                #del i

# %%
def resolution(data) :
    new_data = np.zeros(np.array(data.shape) * 10)

    for j in range(data.shape[0]):
        for k in range(data.shape[1]):
            new_data[j * 10: (j+1) * 10, k * 10: (k+1) * 10] = data[j, k]

    return new_data

# %%
import matplotlib.image as mpimg

road = route(4,15, 0.01)
for j in range(100):
    road.update_route()
    road.state_route
    
    plt.imshow(road.state_route, vmin=0, vmax=13, cmap="hot")
    #plt.imsave("resultat_{}.png".format(j),resolution(road.state_route))
    plt.colorbar()
    plt.show()
    plt.pause(0.1)
    plt.cla()
# Out:
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# 16
# 15
# voiture de la voie 1 supprimee a la position: 11
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# stop
# stop
# 21
# 20
# voiture de la voie 1 supprimee a la position: 5
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
# plop ! une voiture est entrée dans l'autoroute !!
